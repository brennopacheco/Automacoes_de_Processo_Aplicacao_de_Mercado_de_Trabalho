# %% [markdown]
# ### Passo 1 - Importar Arquivos e Bibliotecas

# %%
import pandas as pd

main_path = r"C:\Users\Brenn\Documents\Python 2024\Projeto 01\Bases de Dados"
df_email = pd.read_excel(main_path+r'\Emails.xlsx')
df_lojas = pd.read_csv(main_path+r"\Lojas.csv", sep=';', encoding='latin-1')
df_vendas = pd.read_excel(main_path+r"\Vendas.xlsx")


display(df_email.head(10))
display(df_lojas.head(10))
display(df_vendas.head(10))
# Out:
#                                Loja    Gerente  \
# 0                Iguatemi Esplanada     Helena
# 1              Shopping Midway Mall      Alice
# 2                    Norte Shopping      Laura
# 3       Shopping Iguatemi Fortaleza    Manuela
# 4          Shopping União de Osasco  Valentina
# 5        Shopping Center Interlagos     Sophia
# 6                    Rio Mar Recife   Isabella
# 7                 Salvador Shopping    Heloisa
# 8        Rio Mar Shopping Fortaleza      Luiza
# 9  Shopping Center Leste Aricanduva      Julia
#
#                                      E-mail
# 0     pythonimpressionador+helena@gmail.com
# 1      pythonimpressionador+alice@gmail.com
# 2      pythonimpressionador+laura@gmail.com
# 3    pythonimpressionador+manuela@gmail.com
# 4  pythonimpressionador+valentina@gmail.com
# 5     pythonimpressionador+sophia@gmail.com
# 6   pythonimpressionador+isabella@gmail.com
# 7    pythonimpressionador+heloisa@gmail.com
# ...

# %% [markdown]
# ### Passo 2 - Definir Criar uma Tabela para cada Loja e Definir o dia do Indicador

# %%
df_vendas = df_vendas.merge(df_lojas, on='ID Loja')
df_vendas.info()
display(df_vendas)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100999 entries, 0 to 100998
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Código Venda    100999 non-null  int64
#  1   Data            100999 non-null  datetime64[ns]
#  2   ID Loja         100999 non-null  int64
#  3   Produto         100999 non-null  object
#  4   Quantidade      100999 non-null  int64
#  5   Valor Unitário  100999 non-null  int64
#  6   Valor Final     100999 non-null  int64
#  7   Loja            100999 non-null  object
# dtypes: datetime64[ns](1), int64(5), object(2)
# memory usage: 6.2+ MB
#         Código Venda       Data  ID Loja           Produto  Quantidade  \
# 0                  1 2019-01-01        1    Sapato Estampa           1
# 1                  1 2019-01-01        1          Camiseta           2
# 2                  1 2019-01-01        1     Sapato Xadrez           1
# ...

# %%
df_vendas_lojas = df_vendas.drop(['Data'], axis=1)
df_vendas_lojas = df_vendas_lojas.groupby('Loja').sum()
display(df_vendas_lojas)
# Out:
#                                   Código Venda  ID Loja  \
# Loja
# Bourbon Shopping SP                  142577669    57624
# Center Shopping Uberlândia           138457517    68221
# Iguatemi Campinas                    145499790    98592
# Iguatemi Esplanada                   138859203     3980
# Norte Shopping                       145499571    12537
# Novo Shopping Ribeirão Preto         140372814    93127
# Palladium Shopping Curitiba          145545401    63150
# Parque Dom Pedro Shopping            136735963    50726
# Passei das Águas Shopping            139017557    64000
# Ribeirão Shopping                    140189391    44528
# Rio Mar Recife                       149070473    28693
# Rio Mar Shopping Fortaleza           141379782    37062
# Salvador Shopping                    142839770    32240
# Shopping Barra                       137802790    99050
# Shopping Center Interlagos           139838616    24126
# Shopping Center Leste Aricanduva     142051349    40930
# ...

# %% [markdown]
# ### Passo 3 - Salvar a planilha na pasta de backup

# %% [markdown]
# ### Passo 4 - Calcular o indicador para 1 loja

# %% [markdown]
# ### Passo 5 - Enviar por e-mail para o gerente

# %% [markdown]
# ### Passo 6 - Automatizar todas as lojas

# %% [markdown]
# ### Passo 7 - Criar ranking para diretoria

# %% [markdown]
# ### Passo 8 - Enviar e-mail para diretoria
